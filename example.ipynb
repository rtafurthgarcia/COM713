# %% [markdown]
# # This should work in all cases!

# %%
import ast 
import pandas as pd
import matplotlib.pyplot as plt 

plt.plot([90, 99, 50, 78], [66, 88, 89, 90], "ro")
plt.ylabel("Recall")
plt.xlabel("Precision")
plt.title("SBOM Performance visualisation")
plt.axis((0, 100, 0, 100))
plt.grid(True)
plt.show()

# %% [markdown]
# # This wont be allowed! This is a remote ressource which is forbidden unfortunately

# %%
json = pd.read_json('https://microsoftedge.github.io/Demos/json-dummy-data/5MB.json')
json.tail(6)
# Out:
#                  name language                id  \
# 15834  Zamokuhle Zulu  isiZulu  XU7BX2F8M5PVZ1EF
# 15835   Bhupesh Menon    Hindi  0CEPNRDV98KT3ORP
# 15836    Rohini Vasav    Hindi  UEFML43TCGS04KWM
# 15837    Sunil Kapoor    Hindi  VY2A0APGVHK5NAW2
# 15838  Zamokuhle Zulu  isiZulu  XU7BX2F8M5PVZ1EF
# 15839   Bhupesh Menon    Hindi  0CEPNRDV98KT3ORP
#
#                                                      bio  version
# 15834  Etiam congue dignissim volutpat. Phasellus tin...     8.39
# 15835  Maecenas tempus neque ut porttitor malesuada. ...     2.69
# 15836  Ut accumsan, est vel fringilla varius, purus a...     9.30
# 15837  Proin tempus eu risus nec mattis. Ut dictum, l...     8.04
# 15838  Etiam congue dignissim volutpat. Phasellus tin...     8.39
# 15839  Maecenas tempus neque ut porttitor malesuada. ...     2.69

# %% [markdown]
# # Instead just read it from a file and make sure to join it on the submission date, with the same file name obviously
